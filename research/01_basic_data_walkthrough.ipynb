# %%
import os; os.chdir('..')

# %%
import pandas as pd

# %%
df= pd.read_excel(
    'data/World_Bank_Projects.xls'
)

# %%
df.head()
# Out:
#   World Bank Projects, data as of 10/23/2023 22:00:01 EST  \
# 0                                         Project ID
# 1                                                 id
# 2                                            P502565
# 3                                            P502499
# 4                                            P502493
#
#                     Unnamed: 1                     Unnamed: 2  \
# 0                       Region                        Country
# 1                   regionname                    countryname
# 2   Western and Central Africa            Republic of Liberia
# 3                   South Asia              Republic of India
# 4  Latin America and Caribbean  Federative Republic of Brazil
#
#              Unnamed: 3               Unnamed: 4  \
# 0        Project Status  Last Stage Reached Name
# 1  projectstatusdisplay  last_stage_reached_name
# 2              Pipeline                      NaN
# 3              Pipeline                      NaN
# ...

# %%
df.columns= df.iloc[0]
df.head()
# Out:
# 0  Project ID                       Region                        Country  \
# 0  Project ID                       Region                        Country
# 1          id                   regionname                    countryname
# 2     P502565   Western and Central Africa            Republic of Liberia
# 3     P502499                   South Asia              Republic of India
# 4     P502493  Latin America and Caribbean  Federative Republic of Brazil
#
# 0        Project Status  Last Stage Reached Name  \
# 0        Project Status  Last Stage Reached Name
# 1  projectstatusdisplay  last_stage_reached_name
# 2              Pipeline                      NaN
# 3              Pipeline                      NaN
# 4              Pipeline                      NaN
#
# 0                          Project Name  Project Development Objective   \
# 0                          Project Name  Project Development Objective
# 1                          project_name                             pdo
# ...

# %%
df= df.iloc[2:]
df.head()
# Out:
# 0 Project ID                       Region                        Country  \
# 2    P502565   Western and Central Africa            Republic of Liberia
# 3    P502499                   South Asia              Republic of India
# 4    P502493  Latin America and Caribbean  Federative Republic of Brazil
# 5    P502492  Eastern and Southern Africa            Republic of Burundi
# 6    P502491                   South Asia              Republic of India
#
# 0 Project Status Last Stage Reached Name  \
# 2       Pipeline                     NaN
# 3       Pipeline                     NaN
# 4       Pipeline                     NaN
# 5       Pipeline                     NaN
# 6       Pipeline                     NaN
#
# 0                                       Project Name  \
# 2                                             RIGDPF
# 3               Surat Resilience Enhancement Project
# 4                                        RN Phase II
# 5  Access to Finance to Import Strategic Commodities
# ...

# %%
df.to_csv(
    'data/World_Bank_Projects_Modified.xls',
    index=False
)
