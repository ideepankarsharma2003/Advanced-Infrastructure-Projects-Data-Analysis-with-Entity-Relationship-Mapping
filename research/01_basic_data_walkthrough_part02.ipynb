# %%
import os; os.chdir('..')

# %%
import pandas as pd

# %%
df= pd.read_csv(
    'data/World_Bank_Projects_Modified.xls'
)
df.head()
# Out:
#   Project ID                       Region                        Country  \
# 0    P502565   Western and Central Africa            Republic of Liberia
# 1    P502499                   South Asia              Republic of India
# 2    P502493  Latin America and Caribbean  Federative Republic of Brazil
# 3    P502492  Eastern and Southern Africa            Republic of Burundi
# 4    P502491                   South Asia              Republic of India
#
#   Project Status Last Stage Reached Name  \
# 0       Pipeline                     NaN
# 1       Pipeline                     NaN
# 2       Pipeline                     NaN
# 3       Pipeline                     NaN
# 4       Pipeline                     NaN
#
#                                         Project Name  \
# 0                                             RIGDPF
# 1               Surat Resilience Enhancement Project
# 2                                        RN Phase II
# 3  Access to Finance to Import Strategic Commodities
# ...

# %%
df.describe()
# Out:
#        Current Project Cost  IBRD Commitment   IDA Commitment  \
# count          2.198300e+04      2.213900e+04    2.213900e+04
# mean           1.644503e+08      4.646813e+07    2.846331e+07
# std            1.134729e+09      1.269232e+08    7.278691e+07
# min            0.000000e+00      0.000000e+00    0.000000e+00
# 25%            1.000000e+07      0.000000e+00    0.000000e+00
# 50%            3.320000e+07      0.000000e+00    0.000000e+00
# 75%            1.058500e+08      3.200000e+07    2.300000e+07
# max            9.300700e+10      3.750000e+09    1.500000e+09
#
#        Total IDA and IBRD Commitment  Grant Amount
# count                   2.213900e+04  2.455000e+03
# mean                    7.493144e+07  4.122798e+07
# std                     1.388905e+08  3.168672e+08
# min                     0.000000e+00  0.000000e+00
# 25%                     5.000000e+06  1.000000e+06
# 50%                     2.500000e+07  5.250000e+06
# ...

# %%
df.columns
# Out:
# Index(['Project ID', 'Region', 'Country', 'Project Status',
#        'Last Stage Reached Name', 'Project Name',
#        'Project Development Objective ', 'Implementing Agency',
#        'Consultant Services Required', 'Project URL', 'Board Approval Date',
#        'Project Closing Date', 'Financing Type', 'Current Project Cost',
#        'IBRD Commitment ', 'IDA Commitment', 'Total IDA and IBRD Commitment',
#        'Grant Amount', 'Borrower', 'Lending Instrument',
#        'Environmental Assessment Category', 'Environmental and Social Risk',
#        'Sector 1', 'Sector 2', 'Sector 3', 'Theme 1', 'Theme 2'],
#       dtype='object')

# %% [markdown]
# # Creating the Countries Entity

# %%
country_list= df.Country.unique().tolist()
country_list
# Out:
# ['Republic of Liberia',
#  'Republic of India',
#  'Federative Republic of Brazil',
#  'Republic of Burundi',
#  'Europe and Central Asia',
#  'Burkina Faso',
#  'Republic of Malawi',
#  'Ukraine',
#  'Democratic Republic of the Congo',
#  'Republic of Kazakhstan',
#  'Arab Republic of Egypt',
#  'Central African Republic',
#  'Republic of Zambia',
#  'Kingdom of Lesotho',
#  'Romania',
#  'Republic of Maldives',
#  'Somali Democratic Republic',
#  "Lao People's Democratic Republic",
#  'United Republic of Tanzania',
#  'Republic of Colombia',
#  'Co-operative Republic of Guyana',
#  'Federal Republic of Nigeria',
#  nan,
#  'Republic of Kenya',
#  'Republic of Congo',
#  'Republic of Guinea',
#  'Republic of Benin',
#  "Republic of Cote d'Ivoire",
#  "People's Republic of Bangladesh",
#  'Republic of Indonesia',
#  'Federal Democratic Republic of Ethiopia',
#  'Republic of Tajikistan',
#  'Republic of Mauritius',
#  'Kingdom of Morocco',
#  'Central Asia',
#  'Republic of Turkiye',
# ...

# %%
import json

# %%
json.dump(country_list, open("Entities/countries.json", "w"))

# %%
project_name= df['Project Name'].unique().tolist()
project_name
# Out:
# ['RIGDPF',
#  'Surat Resilience Enhancement Project',
#  'RN Phase II',
#  'Access to Finance to Import Strategic Commodities',
#  'Haryana Clean Air and Sustainable Development Program',
#  'Renewable Energy Scale-up in Europe and Central Asia MPA (ECARES)',
#  'BURKINA FASO - Resilient Learning Communities Project',
#  'ASCENT AFE MPA - Malawi Energy Access Program for Results',
#  'Lifting Education Access and Resilience in times of Need in Ukraine - LEARN',
#  'DRIP-3',
#  'First DRC Climate Resilient and Inclusive Development Policy Financing',
#  'SP PforR KZ',
#  'Egypt Justice',
#  'CAR Accelerating Results in Education',
#  'ZDPBCP',
#  'Lesotho Integrated Transport ,Trade and Logistics Project',
#  'ROMANIA Second DRM Development Policy Loan With a Cat-DDO',
#  'Maldives - PFM',
#  'Ukraine Economic Recovery Policy Operation',
#  'First Somalia Economic Resilience DPF',
#  'SMEMZ',
#  'Frontline',
#  'TZ- Cat DDO',
#  'SCNIP',
#  'ITCP',
# ...
